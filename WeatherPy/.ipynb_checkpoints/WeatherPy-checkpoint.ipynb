# %% [markdown]
# # WeatherPy
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cannonvale
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | nuuk
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | muisne
# Processing Record 7 of Set 1 | shakawe
# Processing Record 8 of Set 1 | duba
# Processing Record 9 of Set 1 | keflavik
# Processing Record 10 of Set 1 | hami
# Processing Record 11 of Set 1 | shyroke
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | coquimbo
# Processing Record 14 of Set 1 | rio grande
# Processing Record 15 of Set 1 | rosario do sul
# Processing Record 16 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | vilyuysk
# Processing Record 19 of Set 1 | xining
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | robore
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_count = city_data_df.count()
city_data_count
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         cannonvale -20.2833  148.7000     22.66        75         100
# 1  port-aux-francais -49.3500   70.2167      5.95        89          99
# 2     puerto natales -51.7236  -72.4875     12.25        47          75
# 3               nuuk  64.1835  -51.7216     -2.66        93          75
# 4             kodiak  57.7900 -152.4072      0.73        69           0
#
#    Wind Speed Country        Date
# 0        2.69      AU  1730750590
# 1       15.81      TF  1730750591
# 2       12.86      CL  1730750592
# 3        3.09      GL  1730750593
# 4        0.00      US  1730750594

# %%
import os

# Create the output_data directory if it doesn't exist
if not os.path.exists("output_data"):
    os.makedirs("output_data")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               cannonvale -20.2833  148.7000     22.66        75         100
# 1        port-aux-francais -49.3500   70.2167      5.95        89          99
# 2           puerto natales -51.7236  -72.4875     12.25        47          75
# 3                     nuuk  64.1835  -51.7216     -2.66        93          75
# 4                   kodiak  57.7900 -152.4072      0.73        69           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.69      AU  1730750590
# 1             15.81      TF  1730750591
# 2             12.86      CL  1730750592
# 3              3.09      GL  1730750593
# 4              0.00      US  1730750594

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Display the columns of the DataFrame
print(city_data_df.columns)
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker='o', color='blue')

# Incorporate the other graph properties
plt.title("Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Temperature (Celsius)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Temperature_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity in World Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def create_linear_regression_plot(x, y, x_label, y_label, title):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    
    # Calculate the regression line values
    regress_values = slope * x + intercept
    
    # Create the scatter plot
    plt.scatter(x, y, marker='o', label='Data Points')
    
    # Plot the regression line
    plt.plot(x, regress_values, color='red', label='Regression Line')
    
    # Incorporate the other graph properties
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend()
    plt.grid(True)
    
    # Show the plot
    plt.show()
    
    # Return the regression parameters for further use if needed
    return slope, intercept, r_value, p_value, std_err

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemisphere_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3            nuuk  64.1835  -51.7216     -2.66        93          75
# 4          kodiak  57.7900 -152.4072      0.73        69           0
# 5          muisne   0.6000  -80.0333     24.48        74         100
# 7            duba  27.3513   35.6901     24.70        46           9
# 8        keflavik  64.0049  -22.5624      7.24        87         100
#
#          Wind Speed Country        Date
# City_ID
# 3              3.09      GL  1730750593
# 4              0.00      US  1730750594
# 5              4.10      EC  1730750595
# 7              5.15      SA  1730750598
# 8              5.66      IS  1730750599

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               cannonvale -20.2833  148.7000     22.66        75         100
# 1        port-aux-francais -49.3500   70.2167      5.95        89          99
# 2           puerto natales -51.7236  -72.4875     12.25        47          75
# 6                  shakawe -18.3667   21.8500     26.01        47         100
# 11                waitangi -43.9535 -176.5597     11.57        77          94
#
#          Wind Speed Country        Date
# City_ID
# 0              2.69      AU  1730750590
# 1             15.81      TF  1730750591
# 2             12.86      CL  1730750592
# 6              3.92      BW  1730750597
# 11             1.34      NZ  1730750602

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere: Temperature vs. Latitude
slope_temp_north, intercept_temp_north, r_value_temp_north, p_value_temp_north, std_err_temp_north = create_linear_regression_plot(
    northern_hemisphere_df["Lat"], 
    northern_hemisphere_df["Max Temp"], 
    x_label='Latitude', 
    y_label='Max Temperature (Celsius)', 
    title='Linear Regression: Temperature vs. Latitude (Northern Hemisphere)'
)

# %%
# Linear regression on Southern Hemisphere
slope_temp_south, intercept_temp_south, r_value_temp_south, p_value_temp_south, std_err_temp_south = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Max Temp"], 
    x_label='Latitude', 
    y_label='Max Temperature (Celsius)', 
    title='Linear Regression: Temperature vs. Latitude (Southern Hemisphere)'
)

# %% [markdown]
# **Discussion about the linear relationship:** The correlation between temperature and Latitude are the same for both hemispheres. The closer the latide is to 0, the higher the temperatures are.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope_humidity_north, intercept_humidity_north, r_value_humidity_north, p_value_humidity_north, std_err_humidity_north = create_linear_regression_plot(
    northern_hemisphere_df["Lat"], 
    northern_hemisphere_df["Humidity"], 
    x_label='Latitude', 
    y_label='Humidity (%)', 
    title='Linear Regression: Humidity vs. Latitude (Northern Hemisphere)'
)

# %%
# Southern Hemisphere
slope_humidity_south, intercept_humidity_south, r_value_humidity_south, p_value_humidity_south, std_err_humidity_south = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Humidity"], 
    x_label='Latitude', 
    y_label='Humidity (%)', 
    title='Linear Regression: Humidity vs. Latitude (Southern Hemisphere)'
)

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be no correlation between latitude and humidity in the northern hemisphere, but there does seem to be a slightly more humidity in latitudes closer to 0 for the southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope_cloudiness_north, intercept_cloudiness_north, r_value_cloudiness_north, p_value_cloudiness_north, std_err_cloudiness_north = create_linear_regression_plot(
    northern_hemisphere_df["Lat"], 
    northern_hemisphere_df["Cloudiness"], 
    x_label='Latitude', 
    y_label='Cloudiness (%)', 
    title='Linear Regression: Cloudiness vs. Latitude (Northern Hemisphere)'
)

# %%
# Southern Hemisphere
slope_cloudiness_south, intercept_cloudiness_south, r_value_cloudiness_south, p_value_cloudiness_south, std_err_cloudiness_south = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Cloudiness"], 
    x_label='Latitude', 
    y_label='Cloudiness (%)', 
    title='Linear Regression: Cloudiness vs. Latitude (Southern Hemisphere)'
)

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness vs Latitude seems to have no correlation to each other in northern and souther hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope_wind_north, intercept_wind_north, r_value_wind_north, p_value_wind_north, std_err_wind_north = create_linear_regression_plot(
    northern_hemisphere_df["Lat"], 
    northern_hemisphere_df["Wind Speed"], 
    x_label='Latitude', 
    y_label='Wind Speed (m/s)', 
    title='Linear Regression: Wind Speed vs. Latitude (Northern Hemisphere)'
)

# %%
# Southern Hemisphere
# YOUR CODE HERE
slope_wind_south, intercept_wind_south, r_value_wind_south, p_value_wind_south, std_err_wind_south = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Wind Speed"], 
    x_label='Latitude', 
    y_label='Wind Speed (m/s)', 
    title='Linear Regression: Wind Speed vs. Latitude (Southern Hemisphere)'
)

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be a slight increase in wind speeds the further away from the center hemisphere for both northern and southern.
