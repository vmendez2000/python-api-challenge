# %% [markdown]
# # VacationPy
# ---

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d69b99d8-358f-4656-85b8-45e8167126b2" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0         cannonvale -20.2833  148.7000     22.66        75
# 1        1  port-aux-francais -49.3500   70.2167      5.95        89
# 2        2     puerto natales -51.7236  -72.4875     12.25        47
# 3        3               nuuk  64.1835  -51.7216     -2.66        93
# 4        4             kodiak  57.7900 -152.4072      0.73        69
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        2.69      AU  1730750590
# 1          99       15.81      TF  1730750591
# 2          75       12.86      CL  1730750592
# 3          75        3.09      GL  1730750593
# 4           0        0.00      US  1730750594

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Display the column names of the DataFrame
column_names = city_data_df.columns
column_names
# Out:
# Index(['City_ID', 'City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    x='Lng',          # Longitude
    y='Lat',         # Latitude
    size='Humidity',  # Size of the point based on humidity
    geo=True,
    tiles='OSM',
    frame_width=800,
    frame_height=600,
    color='City',     # color points by city
    title='City Humidity Map'
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
ideal_weather_df = city_data_df[
    (city_data_df['Humidity'] < 75) &  
    (city_data_df['Cloudiness'] < 30)  
]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
ideal_weather_df.head()
# Out:
#     City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 4         4    kodiak  57.7900 -152.4072      0.73        69           0
# 7         7      duba  27.3513   35.6901     24.70        46           9
# 9         9      hami  42.8000   93.4500      9.47        30           0
# 10       10   shyroke  47.6917   33.2571      3.00        54           6
# 12       12  coquimbo -29.9533  -71.3436     20.85        51           0
#
#     Wind Speed Country        Date
# 4         0.00      US  1730750594
# 7         5.15      SA  1730750598
# 9         1.70      CN  1730750600
# 10        8.57      UA  1730750601
# 12        6.69      CL  1730750603

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df.copy()

# Select the relevant columns: City, Country, Latitude (Lat), Longitude (Lng), and Humidity
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#         City Country      Lat       Lng  Humidity Hotel Name
# 4     kodiak      US  57.7900 -152.4072        69
# 7       duba      SA  27.3513   35.6901        46
# 9       hami      CN  42.8000   93.4500        30
# 10   shyroke      UA  47.6917   33.2571        54
# 12  coquimbo      CL -29.9533  -71.3436        51

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000  # Set the search radius to 10,000 meters
params = {'categories':'accommodation.hotel',\
         'filter':'',\
         'bias':'',\
         'apiKey':geoapify_key,\
         'limit':1}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    
    # Print the coordinates being searched
    print(f"Searching for hotels near: {lat}, {lon}")

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

   # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
#         # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
#     # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# # Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# Searching for hotels near: 57.79, -152.4072
# kodiak - nearest hotel: No hotel found
# Searching for hotels near: 27.3513, 35.6901
# duba - nearest hotel: No hotel found
# Searching for hotels near: 42.8, 93.45
# hami - nearest hotel: Хами
# Searching for hotels near: 47.6917, 33.2571
# shyroke - nearest hotel: Усадьба
# Searching for hotels near: -29.9533, -71.3436
# coquimbo - nearest hotel: Hotel Iberia
# Searching for hotels near: 36.6167, 101.7667
# xining - nearest hotel: Qinghai hotel
# Searching for hotels near: 17.0151, 54.0924
# salalah - nearest hotel: Muscat International Hotel
# Searching for hotels near: 10.8312, 5.8249
# ukata - nearest hotel: No hotel found
# Searching for hotels near: 17.9583, -102.2
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# Searching for hotels near: -4.3222, -40.7108
# ipu - nearest hotel: No hotel found
# Searching for hotels near: -34.4187, 19.2345
# hermanus - nearest hotel: Aloe guest house
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Add hotel names and country to the hotel_df DataFrame for hover information
hotel_df['Hover Info'] = hotel_df['Hotel Name'] + ', ' + hotel_df['Country']

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    x='Lng',          
    y='Lat',         
    size='Humidity',  
    geo=True,
    tiles='OSM',
    frame_width=800,
    frame_height=600,
    color='City',     
    title='City Humidity Map',
    hover_cols=['City', 'Humidity', 'Hotel Name', 'Country']  # Add hover information
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
